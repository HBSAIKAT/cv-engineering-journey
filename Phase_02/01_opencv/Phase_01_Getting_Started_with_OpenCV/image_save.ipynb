# %%
import cv2

image = cv2.imread('random.jpeg')

if image is not None:
    success = cv2.imwrite('random_copy.jpeg', image)
    if success:
        print('Image saved successfully as random_copy.jpeg')
    else:
        print('Failed to save the image.')
else:
    print('Could not read the image.')
# Out:
# Image saved successfully as random_copy.jpeg
