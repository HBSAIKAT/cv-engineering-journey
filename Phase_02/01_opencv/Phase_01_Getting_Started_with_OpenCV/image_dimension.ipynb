# %%
import cv2

image = cv2.imread('random.jpeg')

if image is not None:
    h, w, c = image.shape
    print(f'Image dimensions: {w}x{h}, Channels: {c}')
else:
    print('Could not read the image.')
# Out:
# Image dimensions: 1600x1200, Channels: 3
